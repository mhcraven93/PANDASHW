# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %%
whale_returns_csv = Path("Resources/whale_returns.csv")
whale_returns = pd.read_csv(
    whale_returns_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
whale_returns = whale_returns.sort_index()
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
whale_returns.dropna(inplace=True)
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
algo_returns_csv = Path("Resources/algo_returns.csv")
algo_returns = pd.read_csv(
    algo_returns_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
algo_returns = algo_returns.sort_index()
algo_returns.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
algo_returns.dropna(inplace=True)
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
sp500_history_csv = Path("Resources/sp500_history.csv")
sp500_history = pd.read_csv(
    sp500_history_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp500_history = sp500_history.sort_index()
sp500_history.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
sp500_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp500_history["Close"] = sp500_history["Close"].str.replace('$', '')
sp500_history["Close"] = sp500_history["Close"].astype('float')
sp500_history.dtypes
# Out:
# Close    float64
# dtype: object

# %%
sp500_returns = sp500_history.pct_change()
sp500_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
sp500_returns.dropna(inplace=True)
sp500_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
sp500_returns.rename(columns={"Close": "S&P 500"}, inplace=True)
sp500_returns.head()
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
all_portfolios = pd.concat([whale_returns, algo_returns, sp500_returns], axis="columns", join="inner")
all_portfolios.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# 2015-03-06 -0.011460 -0.014174
# 2015-03-09  0.001303  0.003944

# %%
all_portfolios.plot(figsize=(20, 10), title="Daily Returns")

# %%
cumulative_returns = (1 + all_portfolios).cumprod()
cumulative_returns.plot(figsize=(20, 10), title="Cumulative Returns")

# %%
all_portfolios.plot.box(figsize=(20, 10), title="Portfolio Risk")

# %%
all_portfolios.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# dtype: float64

# %%
sp500_risk = all_portfolios["S&P 500"].std()
all_portfolios.std() > sp500_risk
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# S&P 500                        False
# dtype: bool

# %%
all_portfolios.std() * np.sqrt(252)
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# S&P 500                        0.135786
# dtype: float64

# %%
all_portfolios.rolling(window=21).std().plot(figsize=(20, 10), title="21 Day Rolling Standard Deviation")

# %%
corr_df = all_portfolios.corr()
corr_df.style.background_gradient(cmap="summer")
# Out:
# <style  type="text/css" >
#     #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow0_col1 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow0_col2 {
#             background-color:  #79bc66;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow0_col3 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow0_col4 {
#             background-color:  #309866;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow0_col5 {
#             background-color:  #c1e066;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow0_col6 {
#             background-color:  #c6e266;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow1_col0 {
#             background-color:  #8ec666;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow1_col2 {
#             background-color:  #52a866;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow1_col3 {
#             background-color:  #5bad66;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow1_col4 {
#             background-color:  #209066;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow1_col5 {
#             background-color:  #8cc666;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow1_col6 {
#             background-color:  #8ac466;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow2_col0 {
#             background-color:  #5aac66;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow2_col1 {
#             background-color:  #399c66;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow2_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow2_col3 {
#             background-color:  #2f9766;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow2_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow2_col5 {
#             background-color:  #4ea666;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow2_col6 {
#             background-color:  #7abc66;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow3_col0 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow3_col1 {
#             background-color:  #60b066;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow3_col2 {
#             background-color:  #4fa766;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow3_col4 {
#             background-color:  #279366;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow3_col5 {
#             background-color:  #8fc766;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow3_col6 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow4_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow4_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow4_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow5_col0 {
#             background-color:  #bede66;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow5_col1 {
#             background-color:  #8fc766;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow5_col2 {
#             background-color:  #69b466;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow5_col3 {
#             background-color:  #8fc766;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow5_col4 {
#             background-color:  #259266;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow5_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow5_col6 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow6_col0 {
#             background-color:  #c2e066;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow6_col1 {
#             background-color:  #8cc666;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow6_col2 {
#             background-color:  #8cc666;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow6_col3 {
#             background-color:  #a6d266;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow6_col4 {
#             background-color:  #239166;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow6_col5 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow6_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_0d8dd336_af33_11ea_8dcb_3035adaa0f2a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SOROS FUND MANAGEMENT LLC</th>        <th class="col_heading level0 col1" >PAULSON & CO.INC. </th>        <th class="col_heading level0 col2" >TIGER GLOBAL MANAGEMENT LLC</th>        <th class="col_heading level0 col3" >BERKSHIRE HATHAWAY INC</th>        <th class="col_heading level0 col4" >Algo 1</th>        <th class="col_heading level0 col5" >Algo 2</th>        <th class="col_heading level0 col6" >S&P 500</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0d8dd336_af33_11ea_8dcb_3035adaa0f2alevel0_row0" class="row_heading level0 row0" >SOROS FUND MANAGEMENT LLC</th>
#                         <td id="T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow0_col1" class="data row0 col1" >0.699914</td>
#                         <td id="T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow0_col2" class="data row0 col2" >0.561243</td>
#                         <td id="T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow0_col3" class="data row0 col3" >0.75436</td>
#                         <td id="T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow0_col4" class="data row0 col4" >0.321211</td>
#                         <td id="T_0d8dd336_af33_11ea_8dcb_3035adaa0f2arow0_col5" class="data row0 col5

# %%
covariance = all_portfolios["BERKSHIRE HATHAWAY INC"].rolling(window=60).cov(all_portfolios["S&P 500"])
variance = all_portfolios["S&P 500"].rolling(60).var()
(covariance / variance).plot(figsize=(20, 10), title="Berkshire Hathaway Inc. Beta")

# %%
sharpe_ratios = (all_portfolios.mean() * 252) / (all_portfolios.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# dtype: float64

# %%
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")

# %%
google_historical_csv = Path("Resources/goog_historical.csv")
google_historical = pd.read_csv(
    google_historical_csv, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
google_historical = google_historical.sort_index()
google_historical.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59

# %%
apple_historical_csv = Path("Resources/aapl_historical.csv")
apple_historical = pd.read_csv(
    apple_historical_csv, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
apple_historical = apple_historical.sort_index()
apple_historical.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   AAPL  188.59
# 2018-05-14   AAPL  188.15
# 2018-05-15   AAPL  186.44
# 2018-05-16   AAPL  188.18
# 2018-05-17   AAPL  186.99

# %%
costco_historical_csv = Path("Resources/cost_historical.csv")
costco_historical = pd.read_csv(
    costco_historical_csv, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
costco_historical = costco_historical.sort_index()
costco_historical.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   COST  195.76
# 2018-05-14   COST  195.88
# 2018-05-15   COST  195.48
# 2018-05-16   COST  198.71
# 2018-05-17   COST  199.60

# %%
all_stocks = pd.concat([google_historical, apple_historical, costco_historical], axis="rows", join="inner")
all_stocks.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59

# %%
all_stocks = all_stocks.reset_index()
all_stocks.head()
# Out:
#   Trade DATE Symbol     NOCP
# 0 2018-05-11   GOOG  1098.26
# 1 2018-05-14   GOOG  1100.20
# 2 2018-05-15   GOOG  1079.23
# 3 2018-05-16   GOOG  1081.77
# 4 2018-05-17   GOOG  1078.59

# %%
portfolio = all_stocks.pivot_table(values="NOCP", index="Trade DATE", columns="Symbol")
portfolio.head()
# Out:
# Symbol        AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
daily_returns = portfolio.pct_change().dropna()
daily_returns.head()
# Out:
# Symbol          AAPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339

# %%
weights = [1/3, 1/3, 1/3]
portfolio_returns = daily_returns.dot(weights)
portfolio_returns.head()
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %%
all_portfolios["Custom"] = portfolio_returns
all_portfolios.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2   S&P 500    Custom
# Date
# 2019-04-16  0.002899  0.000509  0.000340
# 2019-04-17 -0.005228 -0.002274  0.009292
# 2019-04-18 -0.001229  0.001579  0.001545
# 2019-04-22 -0.001936  0.001012  0.001217
# 2019-04-23  0.009622  0.008841  0.011959

# %%
all_portfolios.dropna(inplace=True)

# %%
all_portfolios.std() * np.sqrt(252)
# Out:
# SOROS FUND MANAGEMENT LLC      0.146675
# PAULSON & CO.INC.              0.116732
# TIGER GLOBAL MANAGEMENT LLC    0.232531
# BERKSHIRE HATHAWAY INC         0.247155
# Algo 1                         0.133704
# Algo 2                         0.139556
# S&P 500                        0.152054
# Custom                         0.211496
# dtype: float64

# %%
all_portfolios.rolling(window=21).std().plot(figsize=(20, 10), title="21 Day Rolling Standard Deviation")

# %%
covariance = all_portfolios["Custom"].rolling(window=60).cov(all_portfolios["S&P 500"])
variance = all_portfolios["S&P 500"].rolling(60).var()
(covariance / variance).plot(figsize=(20, 10), title="Custom Portfolio Beta")

# %%
sharpe_ratios = (all_portfolios.mean() * 252) / (all_portfolios.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.430713
# PAULSON & CO.INC.              0.258738
# TIGER GLOBAL MANAGEMENT LLC   -1.034216
# BERKSHIRE HATHAWAY INC         0.159756
# Algo 1                         2.035665
# Algo 2                         0.080607
# S&P 500                        0.584820
# Custom                         0.933123
# dtype: float64

# %%
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")

# %%
df = all_portfolios.corr()
df.style.background_gradient(cmap="summer")
# Out:
# <style  type="text/css" >
#     #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow0_col1 {
#             background-color:  #acd666;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow0_col2 {
#             background-color:  #69b466;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow0_col3 {
#             background-color:  #badc66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow0_col4 {
#             background-color:  #40a066;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow0_col5 {
#             background-color:  #c8e366;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow0_col6 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow0_col7 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow1_col0 {
#             background-color:  #afd766;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow1_col2 {
#             background-color:  #6bb566;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow1_col3 {
#             background-color:  #7bbd66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow1_col4 {
#             background-color:  #47a366;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow1_col5 {
#             background-color:  #a8d366;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow1_col6 {
#             background-color:  #abd566;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow1_col7 {
#             background-color:  #84c266;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow2_col0 {
#             background-color:  #369a66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow2_col1 {
#             background-color:  #319866;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow2_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow2_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow2_col5 {
#             background-color:  #118866;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow2_col6 {
#             background-color:  #45a266;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow2_col7 {
#             background-color:  #2d9666;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow3_col0 {
#             background-color:  #b9dc66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow3_col1 {
#             background-color:  #74ba66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow3_col2 {
#             background-color:  #3c9e66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow3_col4 {
#             background-color:  #3d9e66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow3_col5 {
#             background-color:  #a8d366;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow3_col6 {
#             background-color:  #cae466;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow3_col7 {
#             background-color:  #bbdd66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow4_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow4_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow4_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow4_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow5_col0 {
#             background-color:  #cae466;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow5_col1 {
#             background-color:  #a9d466;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow5_col2 {
#             background-color:  #55aa66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow5_col3 {
#             background-color:  #add666;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow5_col4 {
#             background-color:  #48a366;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow5_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow5_col6 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow5_col7 {
#             background-color:  #a5d266;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow6_col0 {
#             background-color:  #d0e866;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow6_col1 {
#             background-color:  #a2d066;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow6_col2 {
#             background-color:  #69b466;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow6_col3 {
#             background-color:  #c7e366;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow6_col4 {
#             background-color:  #329866;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow6_col5 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow6_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow6_col7 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow7_col0 {
#             background-color:  #98cc66;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow7_col1 {
#             background-color:  #71b866;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow7_col2 {
#             background-color:  #50a866;
#             color:  #000000;
#         }    #T_77ed7a06_af33_11ea_8dcb_3035adaa0f2arow7_col3 {
#             background-color:  #b4da66;
#             color:  #000000;
